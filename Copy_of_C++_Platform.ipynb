# %% [markdown]
# <a href="https://colab.research.google.com/github/voyager-09/hscde/blob/master/Copy_of_C%2B%2B_Platform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import folders

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# variables set for file and path

# %%
path="/content/drive/MyDrive/Folder/Hshcde/2020/quals/code/"
file_name="code.cpp"
net_path=path+file_name

# %% [markdown]
#  MAIN CODE

# %%
# %%writefile {net_path}
# /////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
#
# #include<bits/stdc++.h>
# using namespace std;
# #define print(t) cout<<"Case #"<<t<<": "
# #define fastio ios_base::sync_with_stdio(0);cin.tie(0);cout.tie(0)
# #define pi 3.14159265359
# #define endl "\n"
# #define ms(a,x) memset(a,x,sizeof(a))
# #define memo(n,type,start) vector<type>memo(n,start)
# #define vll(v,n) vector<ll>v(n)
# #define rep0(i,n) for(ll i=0;i<=n;i++)
# #define read(v) for(auto &a:v)cin>>a
# #define bidirinput(v,a,b) v[a].push_back(b);v[b].push_back(a)
# #define parity(x)  (x%2)
# #define sort_till_end(v)  sort(v.begin(),v.end())
# #define reverse_till_end(v)  reverse_till_end(v.begin(),v.end())
# #define ll long long
# struct triple{ll first,second,third;void assign(ll a,ll b,ll c){first=a;second=b;third=c;}};
# ll min(ll a,ll b);
# ll max(ll a,ll b);
# void write(vector<auto>v);
# void printv(vector<ll>v,char end_with);
#
#
#
#
#
# int main()
# {
#   fastio;
#   ll t,n,a,tt,p,m;
#   string s,s1,s2;
#   cin>>t;
#   tt=t;
#  t=5;
#   while(t--)
#   {
#        cout<<"a";
#
#
#
#   }
#
#    return 0;
# }
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ll min(ll a,ll b)
# {
#    if(a>=b)return b;
#    return a;
# }
#
#
#
# ll max(ll a,ll b)
# {
#    if(a<=b)return b;
#    return a;
# }
#
# void write(vector<auto>v)
# {
#     for(auto a:v)
#     {
#         cout<<a<<" ";
#     }
#     cout<<endl;
# }
#
# // push_back  pop_back  vector  INT_MAX  IMPOSSIBLE  POSSIBLE length size
# Out:
# Overwriting /content/drive/MyDrive/Folder/Hshcde/2020/quals/code/code.cpp

# %% [markdown]
# FOR COMPILING

# %%
# %%bash
# path="/content/drive/MyDrive/Folder/Hshcde/2020/quals/code/"
# file_name="code.cpp"
# net_path=path+file_name
# cd $path
# g++ $file_name
# ./a.out
