# %% [markdown]
# <a href="https://colab.research.google.com/github/voyager-09/hscde/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# cd ../myfolder/testfolder/
# git clone git@github.com:voyager-09/hscde.git
# git push origin master
# Out:
# Cloning into 'hscde'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# error: src refspec master does not match any.
# error: failed to push some refs to 'origin'

# %%
# %%writefile   ../myfolder/testfolder/main.cpp
# //////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////
# Out:
# Overwriting ../myfolder/testfolder/main.cpp
